# %%
from google.colab import drive

project_directory = '5A/PRD/workspace'

drive.mount('/content/drive')
# %cd drive/My Drive/$project_directory
# %ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/5A/PRD/workspace
# 'Baseline Competition - Simple Documents'/
#  dhSegment-torch/
#  EnvironmentSetup.ipynb
#  FCR/
#  FCR_500/
#  FCR_500.tar.gz
#  PatchDatasets.ipynb
#  __pycache__/
# 'Train - Baseline Competition - Simple Documents.tar.gz'
#  training_data/

# %%
#!pip install git+https://github.com/dhlab-epfl/dhSegment-torch.git@master

# %%
#!tar -xzvf "FCR_500.tar.gz"
#!tar -xzvf "Train - Baseline Competition - Simple Documents.tar.gz"

# %%
import training_data.pipelines as pipe

# %%
for name_dataset in ('fcr', 'bcs_a', 'bcs_b', 'bcs_e', 'bcs_h', 'bcs_n', 'bcs_s', 'bcs_u', 'bcs_un'):
    for names_labels in (['TextRegion'], ['TextLine'], ['TextRegion', 'TextLine']):
        pipe.annotationsToMasks(
            name_dataset= name_dataset,
            names_labels= names_labels
        )

# TODO pipeline according to specific EOC
# Out:
# ...
# Building label masks: 100%|██████████| 500/500 [08:52<00:00,  1.07s/it]
